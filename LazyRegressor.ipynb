# %%
import pandas as pd

# %%
from lazypredict.Supervised import LazyRegressor
# 从 lazypredict.Supervised 中导入分类类
from lazypredict.Supervised import LazyClassifier

# %%
import pandas as pd  
  
# 读取训练集和测试集  
train_df = pd.read_csv(r'C:\Users\13212\Desktop\省肿瘤\3\processed3\train_smote_fold_9.csv', encoding='GBK')  
test_df = pd.read_csv(r'C:\Users\13212\Desktop\省肿瘤\3\processed3\test_fold_9.csv', encoding='GBK')  
  
# 提取特征和标签  
X_train = train_df.iloc[:, :-1]  # 训练集特征：所有行，除了最后一列  
y_train = train_df.iloc[:, -1]   # 训练集标签：所有行的最后一列  
X_test = test_df.iloc[:, :-1]    # 测试集特征：所有行，除了最后一列  
y_test = test_df.iloc[:, -1]     # 测试集标签：所有行的最后一列  
  
# 现在你已经有了X_train, X_test, y_train, y_test，可以进行后续操作了

# %%
# 使用 LazyRegressor 定义模型  
#multiple_ML_model = LazyRegressor(verbose=1, ignore_warnings=True, predictions=True)  
# 对模型进行拟合，同时预测每个模型的输出结果  
#models, predictions = multiple_ML_model.fit(X_train, X_test, y_train, y_test)
# 使用 LazyRegressor 定义模型
multiple_ML_model = LazyClassifier(verbose=1,
          ignore_warnings=True,
          predictions=True)
# 对模型进行拟合，并预测每个模型的输出结果
models, predictions = multiple_ML_model.fit(
          X_train, X_test, y_train, y_test)
# Out:
#   3%|██▊                                                                                | 1/29 [00:00<00:17,  1.61it/s]
# {'Model': 'AdaBoostClassifier', 'Accuracy': 0.6425531914893617, 'Balanced Accuracy': 0.630801687763713, 'ROC AUC': 0.630801687763713, 'F1 Score': 0.6503931438077803, 'Time taken': 0.6226828098297119}
#   7%|█████▋                                                                             | 2/29 [00:01<00:19,  1.40it/s]
# {'Model': 'BaggingClassifier', 'Accuracy': 0.5957446808510638, 'Balanced Accuracy': 0.5955452775073028, 'ROC AUC': 0.5955452775073029, 'F1 Score': 0.6065991139058452, 'Time taken': 0.7719314098358154}
# {'Model': 'BernoulliNB', 'Accuracy': 0.5872340425531914, 'Balanced Accuracy': 0.6110029211295034, 'ROC AUC': 0.6110029211295033, 'F1 Score': 0.5979473421390176, 'Time taken': 0.07687544822692871}
#  21%|█████████████████▏                                                                 | 6/29 [00:03<00:10,  2.26it/s]
# ...

# %%
data = [{'Model': 'AdaBoostClassifier', 'Accuracy': 0.6425531914893617, 'Balanced Accuracy': 0.630801687763713, 'ROC AUC': 0.630801687763713, 'F1 Score': 0.6503931438077803, 'Time taken': 0.6226828098297119},

{'Model': 'BaggingClassifier', 'Accuracy': 0.5957446808510638, 'Balanced Accuracy': 0.5955452775073028, 'ROC AUC': 0.5955452775073029, 'F1 Score': 0.6065991139058452, 'Time taken': 0.7719314098358154},
{'Model': 'BernoulliNB', 'Accuracy': 0.5872340425531914, 'Balanced Accuracy': 0.6110029211295034, 'ROC AUC': 0.6110029211295033, 'F1 Score': 0.5979473421390176, 'Time taken': 0.07687544822692871},

{'Model': 'CalibratedClassifierCV', 'Accuracy': 0.625531914893617, 'Balanced Accuracy': 0.6336011035378124, 'ROC AUC': 0.6336011035378124, 'F1 Score': 0.635788815755906, 'Time taken': 1.5650842189788818},
{'Model': 'Perceptron', 'Accuracy': 0.5957446808510638, 'Balanced Accuracy': 0.5799253489126907, 'ROC AUC': 0.5799253489126907, 'F1 Score': 0.6048714495607559, 'Time taken': 0.03205251693725586},

{'Model': 'QuadraticDiscriminantAnalysis', 'Accuracy': 0.3872340425531915, 'Balanced Accuracy': 0.5228416098669263, 'ROC AUC': 0.5228416098669264, 'F1 Score': 0.29718659021021154, 'Time taken': 0.14789223670959473},

{'Model': 'RandomForestClassifier', 'Accuracy': 0.6808510638297872, 'Balanced Accuracy': 0.6440279130152547, 'ROC AUC': 0.6440279130152547, 'F1 Score': 0.6813415756530584, 'Time taken': 2.104464292526245},
{'Model': 'RidgeClassifier', 'Accuracy': 0.6170212765957447, 'Balanced Accuracy': 0.6303148328464785, 'ROC AUC': 0.6303148328464785, 'F1 Score': 0.6275898463128069, 'Time taken': 0.03727293014526367},

{'Model': 'RidgeClassifierCV', 'Accuracy': 0.6170212765957447, 'Balanced Accuracy': 0.6303148328464785, 'ROC AUC': 0.6303148328464785, 'F1 Score': 0.6275898463128069, 'Time taken': 0.18586063385009766},
{'Model': 'SGDClassifier', 'Accuracy': 0.5787234042553191, 'Balanced Accuracy': 0.5827247646867899, 'ROC AUC': 0.58272476468679, 'F1 Score': 0.590307111925297, 'Time taken': 0.0567624568939209},

{'Model': 'SVC', 'Accuracy': 0.6382978723404256, 'Balanced Accuracy': 0.6119766309639727, 'ROC AUC': 0.6119766309639727, 'F1 Score': 0.6434600682688073, 'Time taken': 0.8762409687042236},

{'Model': 'XGBClassifier', 'Accuracy': 0.6382978723404256, 'Balanced Accuracy': 0.5838607594936709, 'ROC AUC': 0.5838607594936709, 'F1 Score': 0.6338825668314088, 'Time taken': 0.47663402557373047},

{'Model': 'LGBMClassifier', 'Accuracy': 0.6553191489361702, 'Balanced Accuracy': 0.6154251866277183, 'ROC AUC': 0.6154251866277183, 'F1 Score': 0.6558489017053032, 'Time taken': 1.212472915649414}]

df = pd.DataFrame(data)
# 只选择我们感兴趣的列  
df_selected = df[['Model', 'Accuracy', 'Balanced Accuracy', 'ROC AUC', 'F1 Score']]  
  
# 打印DataFrame  
print(df_selected)
# Out:
#                             Model  Accuracy  Balanced Accuracy  ROC AUC  \
# 0              AdaBoostClassifier      0.64               0.63     0.63
# 1               BaggingClassifier      0.60               0.60     0.60
# 2                     BernoulliNB      0.59               0.61     0.61
# 3          CalibratedClassifierCV      0.63               0.63     0.63
# 4          DecisionTreeClassifier      0.59               0.55     0.55
# 5                 DummyClassifier      0.34               0.50     0.50
# 6             ExtraTreeClassifier      0.57               0.56     0.56
# 7            ExtraTreesClassifier      0.62               0.59     0.59
# 8                      GaussianNB      0.43               0.55     0.55
# 9            KNeighborsClassifier      0.54               0.57     0.57
# 10               LabelPropagation      0.57               0.56     0.56
# 11                 LabelSpreading      0.57               0.56     0.56
# ...

# %%
df_selected.to_csv(f'C:\\Users\\13212\\Desktop\\省肿瘤\\3\\model_performance.csv', index=False)
